# %% [markdown]
# <a href="https://www.kaggle.com/code/devgondaliya007/smartphones-data-cleaning?scriptVersionId=294482306" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/smartphones/smartphones - smartphones.csv

# %%
df = pd.read_csv("/kaggle/input/smartphones/smartphones - smartphones.csv")

# %% [markdown]
# # many row contain memory data in model name :

# %%
df['model'].str.contains("GB").sum()
# Out:
# np.int64(240)

# %%
df[df['model'].str.contains("GB")].sample(2)
# Out:
#                                         model    price  rating  \
# 889  Realme Narzo 50A Prime (4GB RAM + 128GB)  ₹11,879    74.0
# 554                 iQOO 7 (12GB RAM + 256GB)  ₹35,990    85.0
#
#                                          sim  \
# 889           Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 554  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                         processor                        ram  \
# 889     Tiger T612, Octa Core, 1.82 GHz Processor   4 GB RAM, 128 GB inbuilt
# 554  Snapdragon 870, Octa Core, 3.2 GHz Processor  12 GB RAM, 256 GB inbuilt
#
#                                      battery  \
# 889  5000 mAh Battery with 18W Fast Charging
# 554  4400 mAh Battery with 66W Fast Charging
#
#                                                display  \
# 889  6.6 inches, 1080 x 2408 px Display with Water ...
# 554  6.62 inches, 1080 x 2400 px, 120 Hz Display wi...
#
#                                                 camera  \
# 889  50 MP + 2 MP + 2 MP Triple Rear & 8 MP Front C...
# 554  48 MP + 13 MP + 2 MP Triple Rear & 16 MP Front...
#
#                                  card           os
# 889  Memory Card Supported, upto 1 TB  Android v11
# 554                       Android v11  No FM Radio

# %%
temp_df = df[df['model'].str.contains("GB")]['model'].str.split('(').str[0]

# %%
df.loc[temp_df.index , 'model'] = temp_df

# %%
df[df['model'].str.contains("TB")]
# Out:
#                              model      price  rating  \
# 290  Apple iPhone 14 Pro Max (1TB)  ₹1,82,999    78.0
# 781  Apple iPhone 13 Pro Max (1TB)  ₹1,79,900    86.0
# 814      Apple iPhone 14 Pro (1TB)  ₹1,72,999    77.0
# 961      Apple iPhone 13 Pro (1TB)  ₹1,47,900    84.0
#
#                                          sim  \
# 290  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 781  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 814  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 961  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                      processor                     ram  \
# 290           Bionic  A16, Hexa Core Processor  6 GB RAM, 1 TB inbuilt
# 781  Bionic A15, Hexa Core, 3.22 GHz Processor  6 GB RAM, 1 TB inbuilt
# 814           Bionic  A16, Hexa Core Processor  6 GB RAM, 1 TB inbuilt
# 961  Bionic A15, Hexa Core, 3.22 GHz Processor  6 GB RAM, 1 TB inbuilt
#
#                                  battery  \
# 290  4323 mAh Battery with Fast Charging
# 781  4352 mAh Battery with Fast Charging
# 814  3200 mAh Battery with Fast Charging
# 961  3095 mAh Battery with Fast Charging
#
#                                                display  \
# 290         6.7 inches, 1290 x 2796 px, 120 Hz Display
# 781  6.7 inches, 1284 x 2778 px, 120 Hz Display wit...
# 814         6.1 inches, 1179 x 2556 px, 120 Hz Display
# 961  6.1 inches, 1170 x 2532 px, 120 Hz Display wit...
#
#                                                 camera  \
# 290  48 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 781  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 814  48 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 961  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
#
#                           card         os
# 290  Memory Card Not Supported    iOS v16
# 781  Memory Card Not Supported    iOS v15
# 814  Memory Card Not Supported    iOS v16
# 961  Memory Card Not Supported  iOS v15.0

# %%
temp_df = df[df['model'].str.contains("TB")]['model'].str.split("(").str[0]

# %%
df.loc[temp_df.index , 'model'] = temp_df

# %% [markdown]
# ### row contain a charging speed in model name :

# %%
df.loc[235 , 'model']
# Out:
# 'Vivo T1 44W'

# %%
df.loc[235 , 'model'] = 'Vivo T1'

# %% [markdown]
# #### one row replaced Redmi to Mi in model name

# %%
df.loc[[462,470] , 'model']
# Out:
# 462         Xiaomi Mi Mix Alpha
# 470    Xiaomi Mi 11 Lite NE 5G
# Name: model, dtype: object

# %%
df.loc[[462,470] , 'model'] = ['Xiaomi Redmi Mix Alpha' , 'Xiaomi Redmi 11 Lite NE 5G']

# %% [markdown]
# #### one data is not a smartphone it is a ipod

# %%
df.loc[754 , 'model']
# Out:
# 'Apple iPod Touch (7th Gen)'

# %%
df.drop(754,inplace=True)

# %% [markdown]
# #### there are some model name which is combined with the launch year

# %%
df.loc[[268,273,707,709,778,801,917,986,994,995]]
# Out:
#                             model      price  rating  \
# 268        Redmi Note 11 Pro 2023    ₹18,999    81.0
# 273       Infinix Note 12i (2022)     ₹9,999    73.0
# 707       Samsung Galaxy M21 2021    ₹11,725    76.0
# 709                   OPPO X 2021  ₹1,34,999    86.0
# 778           Tecno Spark Go 2022     ₹6,249    61.0
# 801               Vivo Y11 (2019)     ₹9,490    64.0
# 917              Nokia 150 (2020)     ₹2,499     NaN
# 986               Vivo Y21 (2020)     ₹9,990    65.0
# 994  Samsung Galaxy A9 Pro (2019)    ₹39,990    78.0
# 995      Samsung Galaxy A7 (2018)    ₹21,490    70.0
#
#                                             sim  \
# 268  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, IR Blaster
# 273              Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 707              Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 709            Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 778              Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 801              Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 917                                    Dual Sim
# 986              Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 994         Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC
# 995              Dual Sim, 3G, 4G, VoLTE, Wi-Fi
#
#                                          processor                       ram  \
# 268   Snapdragon 712, Octa Core, 2.3 GHz Processor  6 GB RAM, 128 GB inbuilt
# 273          Helio G85, Octa Core, 2 GHz Processor   4 GB RAM, 64 GB inbuilt
# 707      Exynos 9611, Octa Core, 2.3 GHz Processor   4 GB RAM, 64 GB inbuilt
# 709  Snapdragon 865, Octa Core, 2.84 GHz Processor  8 GB RAM, 256 GB inbuilt
# 778                   Octa Core, 2.2 GHz Processor   2 GB RAM, 32 GB inbuilt
# 801     Snapdragon 439, Octa Core, 2 GHz Processor   3 GB RAM, 32 GB inbuilt
# 917                                        No Wifi              4 MB inbuilt
# 986   Snapdragon 450, Octa Core, 1.8 GHz Processor   4 GB RAM, 64 GB inbuilt
# 994   Snapdragon 710, Octa Core, 2.2 GHz Processor  6 GB RAM, 128 GB inbuilt
# 995      Exynos 7885, Octa Core, 2.2 GHz Processor   4 GB RAM, 64 GB inbuilt
#
#                                      battery  \
# 268  5000 mAh Battery with 67W Fast Charging
# 273  5000 mAh Battery with 33W Fast Charging
# 707  6000 mAh Battery with 15W Fast Charging
# 709  4000 mAh Battery with 45W Fast Charging
# 778                         5000 mAh Battery
# 801                         5000 mAh Battery
# 917                         1020 mAh Battery
# 986                         5000 mAh Battery
# 994      3400 mAh Battery with Fast Charging
# 995                         3300 mAh Battery
#
#                                                display  \
# 268  6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 273  6.7 inches, 1080 x 2400 px Display with Water ...
# 707  6.4 inches, 1080 x 2340 px Display with Water ...
# 709                 7.4 inches, 1440 x 3200 px Display
# 778  6.51 inches, 720 x 1600 px Display with Water ...
# 801  6.35 inches, 720 x 1544 px Display with Water ...
# 917                   2.4 inches, 240 x 320 px Display
# 986  6.5 inches, 720 x 1544 px Display with Water D...
# 994  6.4 inches, 1080 x 2340 px Display with Punch ...
# 995                   6 inches, 2220 x 1080 px Display
#
#                                                 camera  \
# 268              108 MP Quad Rear & 16 MP Front Camera
# 273       50 MP + 2 MP Triple Rear & 8 MP Front Camera
# 707  48 MP + 8 MP + 5 MP Triple Rear & 20 MP Front ...
# 709                                       Dual Display
# 778         13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 801         13 MP + 2 MP Dual Rear & 8 MP Front Camera
# 917                                 0.3 MP Rear Camera
# 986        13 MP + 2 MP Dual Rear & 13 MP Front Camera
# 994  24 MP + 10 MP + 5 MP Triple Rear & 24 MP Front...
# 995  24 MP + 8 MP + 5 MP Triple Rear & 24 MP Front ...
#
#                                                   card                   os
# 268                    Memory Card (Hybrid), upto 1 TB          Android v11
# 273                 Memory Card Supported, upto 512 GB          Android v12
# 707                 Memory Card Supported, upto 512 GB          Android v11
# 709  64 MP + 16 MP + 12 MP Triple Rear & 16 MP Fron...          Android v11
# 778                 Memory Card Supported, upto 256 GB          Android v11
# 801                 Memory Card Supported, upto 256 GB   Android v9.0 (Pie)
# 917                  Memory Card Supported, upto 32 GB            Bluetooth
# 986                 Memory Card Supported, upto 256 GB          Android v10
# 994                 Memory Card Supported, upto 512 GB   Android v9.0 (Pie)
# 995                 Memory Card Supported, upto 512 GB  Android v8.0 (Oreo)

# %%
temp_df = df.loc[[268,273,707,709,778,801,917,986,994,995],'model']

# %%
# here s a regular expression which replace year with '' :
temp_df.str.replace(r'\s?\(?\d{4}\)?$', '', regex=True).str.strip()
# Out:
# 268        Redmi Note 11 Pro
# 273         Infinix Note 12i
# 707       Samsung Galaxy M21
# 709                   OPPO X
# 778           Tecno Spark Go
# 801                 Vivo Y11
# 917                Nokia 150
# 986                 Vivo Y21
# 994    Samsung Galaxy A9 Pro
# 995        Samsung Galaxy A7
# Name: model, dtype: object

# %%
df.loc[temp_df.index , 'model'] = temp_df.str.replace(r'\s?\(?\d{4}\)?$', '', regex=True).str.strip()

# %% [markdown]
# > #### Though this is a smartphone data , there are many Feacher phone ( keypad phone ) so we have to drop that phones

# %%
df.iloc[[478,481,573,532,575,611,647,658,699,757,816,828,851,872,880,881,924,929,931,925,926,1004]]
# Out:
#                               model    price  rating  \
# 478                     Lyf Earth 1   ₹3,990    60.0
# 481                    Itel A24 Pro   ₹5,990     NaN
# 573                Nokia 105 (2019)   ₹1,299     NaN
# 532   Samsung Guru Music 2 Dual Sim   ₹1,949     NaN
# 575                        Lyf C459   ₹1,999     NaN
# 611                 Eunity U1 5605N     ₹699     NaN
# 647               Motorola Moto A10   ₹1,339     NaN
# 658                Letv Y1 Pro Plus   ₹5,999    60.0
# 699           Samsung Guru GT-E1215   ₹1,850     NaN
# 758                       iKall Z19   ₹7,999    61.0
# 817                    itel Magic X   ₹2,239     NaN
# 829           Infinix Note 12 (G96)  ₹16,999    79.0
# 852                    Nokia 215 4G   ₹3,099     NaN
# 873              BlackZone Ultra 4G   ₹1,899     NaN
# 881                Nokia 110 (2022)   ₹1,599     NaN
# 882          Nokia 5710 XpressAudio   ₹4,799     NaN
# 925                   Nokia 3310 4G   ₹3,999     NaN
# 930                iKall K88 Pro 4G   ₹2,099     NaN
# 932                  Eunity U1 Livo     ₹649     NaN
# 926                     Lyf Earth 2   ₹3,890     NaN
# 927              Samsung Guru E1200   ₹1,685     NaN
# 1005                      iKall Z18   ₹6,799    61.0
#
#                                  sim  \
# 478   Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 481          Dual Sim, 3G, 4G, Wi-Fi
# 573                       Single Sim
# 532                         Dual Sim
# 575   Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 611                         Dual Sim
# 647                         Dual Sim
# 658   Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 699                       Single Sim
# 758   Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 817   Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 829   Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 852          Dual Sim, 3G, 4G, VoLTE
# 873          Dual Sim, 3G, 4G, VoLTE
# 881                         Dual Sim
# 882                 Dual Sim, 3G, 4G
# 925   Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 930          Dual Sim, 3G, 4G, VoLTE
# 932                         Dual Sim
# 926   Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 927                       Single Sim
# 1005  Dual Sim, 3G, 4G, VoLTE, Wi-Fi
#
#                                              processor  \
# 478       Snapdragon 615, Octa Core, 1.5 GHz Processor
# 481      Unisoc  SC9832E, Quad Core, 1.4 GHz Processor
# 573                                            No Wifi
# 532                                            No Wifi
# 575   Snapdragon MSM8909, Quad Core, 1.1 GHz Processor
# 611                                              No 3G
# 647                             4 MB RAM, 4 MB inbuilt
# 658           Tiger T610, Quad Core, 1.8 GHz Processor
# 699                                    800 mAh Battery
# 758                       Quad Core, 1.6 GHz Processor
# 817                                              No 3G
# 829           Helio G96, Octa Core, 2.05 GHz Processor
# 852                                        Unisoc T117
# 873                       Single Core, 1 GHz Processor
# 881                                            No Wifi
# 882                                            No Wifi
# 925                         256 MB RAM, 512 MB inbuilt
# 930                          48 MB RAM, 128 MB inbuilt
# 932                                 1.77 MHz Processor
# 926   Snapdragon MSM8939, Octa Core, 1.5 GHz Processor
# 927                                            No Wifi
# 1005                      Quad Core, 1.3 GHz Processor
#
#                                    ram  \
# 478            3 GB RAM, 32 GB inbuilt
# 481            2 GB RAM, 32 GB inbuilt
# 573             4 MB RAM, 4 MB inbuilt
# 532     Single Core, 208 MHz Processor
# 575             1 GB RAM, 8 GB inbuilt
# 611       Dual Core, 500 MHz Processor
# 647                   1750 mAh Battery
# 658            6 GB RAM, 64 GB inbuilt
# 699   1.5 inches, 120 x 120 px Display
# 758            4 GB RAM, 32 GB inbuilt
# 817                               T117
# 829           8 GB RAM, 128 GB inbuilt
# 852          64 MB RAM, 128 MB inbuilt
# 873           48 MB RAM, 48 MB inbuilt
# 881             4 MB RAM, 4 MB inbuilt
# 882                        Unisoc T107
# 925                   1200 mAh Battery
# 930                   1800 mAh Battery
# 932           16 MB RAM, 16 MB inbuilt
# 926            3 GB RAM, 32 GB inbuilt
# 927                    800 mAh Battery
# 1005           4 GB RAM, 64 GB inbuilt
#
#                                       battery  \
# 478                          3500 mAh Battery
# 481                          3020 mAh Battery
# 573                           800 mAh Battery
# 532                           800 mAh Battery
# 575                          2000 mAh Battery
# 611                  32 MB RAM, 32 MB inbuilt
# 647          1.8 inches, 160 x 128 px Display
# 658   4000 mAh Battery with 10W Fast Charging
# 699                            No Rear Camera
# 758                          5000 mAh Battery
# 817                 48 MB RAM, 128 MB inbuilt
# 829   5000 mAh Battery with 33W Fast Charging
# 852                          1150 mAh Battery
# 873                          2500 mAh Battery
# 881                          1000 mAh Battery
# 882                 48 MB RAM, 128 MB inbuilt
# 925          2.4 inches, 240 x 320 px Display
# 930          2.4 inches, 240 x 360 px Display
# 932                          1000 mAh Battery
# 926                          2500 mAh Battery
# 927          1.5 inches, 128 x 128 px Display
# 1005                         5000 mAh Battery
#
#                                                 display  \
# 478                  5.5 inches, 1080 x 1920 px Display
# 481                      5 inches, 854 x 480 px Display
# 573                   1.77 inches, 120 x 160 px Display
# 532                      2 inches, 128 x 160 px Display
# 575                    4.5 inches, 480 x 854 px Display
# 611                                    3000 mAh Battery
# 647                                      No Rear Camera
# 658   6.5 inches, 720 x 1560 px Display with Small N...
# 699                                         No FM Radio
# 758   6.5 inches, 720 x 1600 px Display with Water D...
# 817                                    1200 mAh Battery
# 829   6.7 inches, 1080 x 2400 px Display with Punch ...
# 852                    2.4 inches, 240 x 320 px Display
# 873                    1.8 inches, 480 x 640 px Display
# 881                   1.77 inches, 120 x 160 px Display
# 882                                    1450 mAh Battery
# 925                                    2 MP Rear Camera
# 930                                  0.3 MP Rear Camera
# 932                    1.8 inches, 280 x 240 px Display
# 926                    5 inches, 1080 x 1920 px Display
# 927                                      No Rear Camera
# 1005  6.82 inches, 720 x 1560 px Display with Punch ...
#
#                                                  camera  \
# 478          13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 481                     2 MP Rear & 0.3 MP Front Camera
# 573                                      No Rear Camera
# 532                                      No Rear Camera
# 575                       5 MP Rear & 2 MP Front Camera
# 611                    1.8 inches, 128 x 160 px Display
# 647                   Memory Card Supported, upto 32 GB
# 658   8 MP + Depth Sensor Dual Rear & 5 MP Front Camera
# 699                                                 NaN
# 758                     20 MP Rear & 13 MP Front Camera
# 817                    2.4 inches, 240 x 320 px Display
# 829       50 MP + 2 MP Triple Rear & 16 MP Front Camera
# 852                                      No Rear Camera
# 873                                    2 MP Rear Camera
# 881                   Memory Card Supported, upto 32 GB
# 882                    2.4 inches, 240 x 320 px Display
# 925                   Memory Card Supported, upto 32 GB
# 930                  Memory Card Supported, upto 128 GB
# 932                                  0.3 MP Rear Camera
# 926                     13 MP Rear & 13 MP Front Camera
# 927                                         No FM Radio
# 1005                    20 MP Rear & 13 MP Front Camera
#
#                                    card                                 os
# 478    Memory Card (Hybrid), upto 64 GB          Android v5.1.1 (Lollipop)
# 481               Memory Card Supported                        Android v12
# 573                                 NaN                                NaN
# 532   Memory Card Supported, upto 16 GB                                NaN
# 575   Memory Card Supported, upto 32 GB         Android v6.0 (Marshmallow)
# 611                  0.3 MP Rear Camera  Memory Card Supported, upto 16 GB
# 647                                 NaN                                NaN
# 658                         Android v11                        No FM Radio
# 699                                 NaN                                NaN
# 758   Memory Card (Hybrid), upto 128 GB                      Android v11.0
# 817                  1.3 MP Rear Camera  Memory Card Supported, upto 64 GB
# 829               Memory Card Supported                        Android v12
# 852   Memory Card Supported, upto 32 GB                  RTOS (Series 30+)
# 873   Memory Card Supported, upto 48 GB                          Bluetooth
# 881                                 NaN                                NaN
# 882                  0.3 MP Rear Camera  Memory Card Supported, upto 32 GB
# 925                           Bluetooth                            Browser
# 930                           Bluetooth                            Browser
# 932                                 NaN                                NaN
# 926    Memory Card (Hybrid), upto 64 GB          Android v5.1.1 (Lollipop)
# 927                                 NaN                                NaN
# 1005   Memory Card (Hybrid), upto 64 GB                      Android v10.0

# %%
# we have no any option we have to drop this rows

df = df.drop([478, 481, 573, 532, 575, 611, 647, 658, 699, 757, 816, 828, 851, 872, 880, 881, 924, 929, 931, 925, 926, 1004])

# %% [markdown]
# ### we have to check that any phone has price lower than 4k

# %%
# so we have to convert price col data type into int & remove rupee sign

df['price'] = df['price'].astype(str).str.replace('[₹,]', '', regex=True).astype(int)

# %%
df[df['price'] < 4000] # 190 , 400 is a smartphones and others are feacher phones
# Out:
#                     model  price  rating                             sim  \
# 190            Realme C2s   3499    63.0  Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 400        Jio JioPhone 2   2999     NaN  Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 473          Nokia 110 4G   1762     NaN         Dual Sim, 3G, 4G, VoLTE
# 533       Itel MagicX Pro   2799     NaN  Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 551       itel Magic 2 4G   2399     NaN  Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 582         Nokia 8210 4G   3749     NaN                Dual Sim, 3G, 4G
# 608     Namotel Achhe Din     99     NaN             Dual Sim, 3G, Wi-Fi
# 627          Nokia 225 4G   3589     NaN         Dual Sim, 3G, 4G, VoLTE
# 640        Nokia 105 Plus   1299     NaN                        Dual Sim
# 657         Zanco Tiny T1   2799     NaN                      Single Sim
# 665          itel it2163S    958     NaN                        Dual Sim
# 685          Xiaomi Qin 1   1799     NaN                 Dual Sim, Wi-Fi
# 748          Nokia 400 4G   3290     NaN      Dual Sim, 4G, VoLTE, Wi-Fi
# 817          itel Magic X   2239     NaN  Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 835        Eunity U1 King    599     NaN                        Dual Sim
# 846         DIZO Star 500   1749     NaN                        Dual Sim
# 852          Nokia 215 4G   3099     NaN         Dual Sim, 3G, 4G, VoLTE
# 873    BlackZone Ultra 4G   1899     NaN         Dual Sim, 3G, 4G, VoLTE
# 907          Itel A23 Pro   3999     NaN         Dual Sim, 3G, 4G, Wi-Fi
# 917             Nokia 150   2499     NaN                        Dual Sim
# 927    Samsung Guru E1200   1685     NaN                      Single Sim
# 930      iKall K88 Pro 4G   2099     NaN         Dual Sim, 3G, 4G, VoLTE
# 932        Eunity U1 Livo    649     NaN                        Dual Sim
# 988   Nokia 5310 Dual Sim   3399     NaN                        Dual Sim
# 1000      XTouch F40 Flip   1999     NaN                        Dual Sim
#
#                                               processor  \
# 190             Helio  P22 , Octa Core, 2 GHz Processor
# 400                          Dual Core, 1 GHz Processor
# 473                                             No Wifi
# 533                                     1 GHz Processor
# 551                                               No 3G
# 582                                             No Wifi
# 608                              1 GB RAM, 4 GB inbuilt
# 627                                         Unisoc T117
# 640                              4 MB RAM, 4 MB inbuilt
# 657                            32 MB RAM, 32 MB inbuilt
# 665                              4 MB RAM, 4 MB inbuilt
# 685                                       Helio MT6260A
# 748                                    2000 mAh Battery
# 817                                               No 3G
# 835                                  1.77 MHz Processor
# 846                           SC6531E, 26 MHz Processor
# 852                                         Unisoc T117
# 873                        Single Core, 1 GHz Processor
# 907   Spreadtrum  SC9832E , Quad Core, 1.4 GHz Proce...
# 917                                             No Wifi
# 927                                             No Wifi
# 930                           48 MB RAM, 128 MB inbuilt
# 932                                  1.77 MHz Processor
# 988                             8 MB RAM, 16 MB inbuilt
# 1000                                              No 3G
#
#                                    ram                            battery  \
# 190            3 GB RAM, 32 GB inbuilt                   4000 mAh Battery
# 400           512 MB RAM, 4 GB inbuilt                   2000 mAh Battery
# 473          128 MB RAM, 48 MB inbuilt                   1020 mAh Battery
# 533          64 MB RAM, 128 MB inbuilt                   2500 mAh Battery
# 551                               T117          64 MB RAM, 128 MB inbuilt
# 582                        Unisoc T107          48 MB RAM, 128 MB inbuilt
# 608                   1325 mAh Battery    4 inches, 720 x 1280 px Display
# 627          64 MB RAM, 128 MB inbuilt                   1150 mAh Battery
# 640                    800 mAh Battery  1.77 inches, 128 x 160 px Display
# 657                    200 mAh Battery    0.49 inches, 64 x 32 px Display
# 665                   1200 mAh Battery   1.8 inches, 160 x 128 px Display
# 685            8 MB RAM, 16 MB inbuilt                   1480 mAh Battery
# 748   2.4 inches, 240 x 320 px Display  0.3 MP Rear & 0.3 MP Front Camera
# 817                               T117          48 MB RAM, 128 MB inbuilt
# 835           32 MB RAM, 32 MB inbuilt                   1000 mAh Battery
# 846           32 MB RAM, 32 MB inbuilt                   1900 mAh Battery
# 852          64 MB RAM, 128 MB inbuilt                   1150 mAh Battery
# 873           48 MB RAM, 48 MB inbuilt                   2500 mAh Battery
# 907             1 GB RAM, 8 GB inbuilt                   2400 mAh Battery
# 917                       4 MB inbuilt                   1020 mAh Battery
# 927                    800 mAh Battery   1.5 inches, 128 x 128 px Display
# 930                   1800 mAh Battery   2.4 inches, 240 x 360 px Display
# 932           16 MB RAM, 16 MB inbuilt                   1000 mAh Battery
# 988                   1200 mAh Battery   2.4 inches, 240 x 320 px Display
# 1000                           No Wifi           32 MB RAM, 32 MB inbuilt
#
#                                                 display  \
# 190   6.1 inches, 720 x 1560 px Display with Water D...
# 400                    2.4 inches, 320 x 240 px Display
# 473                    1.8 inches, 120 x 160 px Display
# 533                    2.4 inches, 320 x 240 px Display
# 551                                    1900 mAh Battery
# 582                                    1450 mAh Battery
# 608                     2 MP Rear & 0.3 MP Front Camera
# 627                    2.4 inches, 240 x 320 px Display
# 640                                      No Rear Camera
# 657                                      No Rear Camera
# 665                                      No Rear Camera
# 685                    2.8 inches, 240 x 320 px Display
# 748                   Memory Card Supported, upto 64 GB
# 817                                    1200 mAh Battery
# 835                    1.8 inches, 260 x 240 px Display
# 846                    2.8 inches, 240 x 320 px Display
# 852                    2.4 inches, 240 x 320 px Display
# 873                    1.8 inches, 480 x 640 px Display
# 907                      5 inches, 854 x 480 px Display
# 917                    2.4 inches, 240 x 320 px Display
# 927                                      No Rear Camera
# 930                                  0.3 MP Rear Camera
# 932                    1.8 inches, 280 x 240 px Display
# 988                                  0.3 MP Rear Camera
# 1000                                    800 mAh Battery
#
#                                           camera  \
# 190   13 MP + 2 MP Dual Rear & 5 MP Front Camera
# 400              2 MP Rear & 0.3 MP Front Camera
# 473                           0.3 MP Rear Camera
# 533                           0.3 MP Rear Camera
# 551             2.4 inches, 240 x 320 px Display
# 582             2.8 inches, 240 x 320 px Display
# 608                      Android v5.0 (Lollipop)
# 627                           0.3 MP Rear Camera
# 640            Memory Card Supported, upto 32 GB
# 657                                  No FM Radio
# 665            Memory Card Supported, upto 32 GB
# 685                               No Rear Camera
# 748                                    Bluetooth
# 817             2.4 inches, 240 x 320 px Display
# 835                           0.3 MP Rear Camera
# 846                           0.3 MP Rear Camera
# 852                               No Rear Camera
# 873                             2 MP Rear Camera
# 907                5 MP Rear & 2 MP Front Camera
# 917                           0.3 MP Rear Camera
# 927                                  No FM Radio
# 930           Memory Card Supported, upto 128 GB
# 932                           0.3 MP Rear Camera
# 988            Memory Card Supported, upto 32 GB
# 1000           1.77 inches, 240 x 320 px Display
#
#                                     card                                 os
# 190   Memory Card Supported, upto 128 GB                 Android v9.0 (Pie)
# 400   Memory Card Supported, upto 128 GB                             KAI OS
# 473    Memory Card Supported, upto 32 GB                                NaN
# 533    Memory Card Supported, upto 64 GB                          Bluetooth
# 551                   1.3 MP Rear Camera  Memory Card Supported, upto 64 GB
# 582                   0.3 MP Rear Camera  Memory Card Supported, upto 32 GB
# 608                            Bluetooth                                NaN
# 627    Memory Card Supported, upto 32 GB                  RTOS (Series 30+)
# 640                            Bluetooth                                NaN
# 657                            Bluetooth                                NaN
# 665                            Bluetooth                                NaN
# 685                              Nucleus                        No FM Radio
# 748                              Browser                                NaN
# 817                   1.3 MP Rear Camera  Memory Card Supported, upto 64 GB
# 835                                  NaN                                NaN
# 846    Memory Card Supported, upto 64 GB                          Bluetooth
# 852    Memory Card Supported, upto 32 GB                  RTOS (Series 30+)
# 873    Memory Card Supported, upto 48 GB                          Bluetooth
# 907                          Android v10                        No FM Radio
# 917    Memory Card Supported, upto 32 GB                          Bluetooth
# 927                                  NaN                                NaN
# 930                            Bluetooth                            Browser
# 932                                  NaN                                NaN
# 988                            Bluetooth                            Browser
# 1000                        Dual Display                 1.3 MP Rear Camera

# %%
df.drop([473,  533,  551,  582,  608,  627,  640,  657,  665,  685,
        748,  817,  835,  846,  852,  873,  907,  917,  927,  930,  932,  988,
       1000],inplace = True)

# %%
# reset index of our dataset 

df = df.reset_index(drop=True)

# %%
df[df['sim'].str.contains('IR Blaster')]
# Out:
#                                 model   price  rating  \
# 7       Xiaomi Redmi Note 12 Pro Plus   29999    86.0
# 12        Xiaomi Redmi Note 12 Pro 5G   24762    79.0
# 22                     Poco X4 Pro 5G   14999    80.0
# 23               Xiaomi Redmi Note 12   17859    76.0
# 31                        Poco X5 Pro   20999    81.0
# ..                                ...     ...     ...
# 946  Huawei Mate 30 RS Porsche Design  214990     NaN
# 949                     Huawei Mate X  169000     NaN
# 961                         Xiaomi 14   54999    89.0
# 963                     Xiaomi Civi 3   32990    86.0
# 971                    POCO X4 GT 5G    28990    85.0
#
#                                                    sim  \
# 7       Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 12      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 22      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 23      Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, IR Blaster
# 31   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# ..                                                 ...
# 946  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 949  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 961  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G, Wi-Fi, NFC,...
# 963  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 971  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
#
#                                            processor  \
# 7       Dimensity 1080, Octa Core, 2.6 GHz Processor
# 12      Dimensity 1080, Octa Core, 2.6 GHz Processor
# 22     Snapdragon 695 , Octa Core, 2.2 GHz Processor
# 23    Snapdragon 4 Gen 1, Octa Core, 2 GHz Processor
# 31     Snapdragon 778G, Octa Core, 2.4 GHz Processor
# ..                                               ...
# 946        Kirin  990, Octa Core, 2.86 GHz Processor
# 949        Kirin  990, Octa Core, 2.86 GHz Processor
# 961  Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
# 963     Dimensity 8200, Octa Core, 3.1 GHz Processor
# 971    Dimensity 8100, Octa Core, 2.85 GHz Processor
#
#                            ram                                   battery  \
# 7     8 GB RAM, 256 GB inbuilt  4980 mAh Battery with 120W Fast Charging
# 12    6 GB RAM, 128 GB inbuilt   5000 mAh Battery with 67W Fast Charging
# 22     6 GB RAM, 64 GB inbuilt   5000 mAh Battery with 67W Fast Charging
# 23    4 GB RAM, 128 GB inbuilt   5000 mAh Battery with 33W Fast Charging
# 31    6 GB RAM, 128 GB inbuilt   5000 mAh Battery with 67W Fast Charging
# ..                         ...                                       ...
# 946  12 GB RAM, 512 GB inbuilt       4500 mAh Battery with Fast Charging
# 949   8 GB RAM, 512 GB inbuilt   4500 mAh Battery with 55W Fast Charging
# 961  12 GB RAM, 256 GB inbuilt   5000 mAh Battery with 67W Fast Charging
# 963   8 GB RAM, 256 GB inbuilt   5000 mAh Battery with 80W Fast Charging
# 971   8 GB RAM, 256 GB inbuilt   5080 mAh Battery with 67W Fast Charging
#
#                                                display  \
# 7    6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 12   6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 22   6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 23   6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# 31   6.67 inches, 1080 x 2400 px, 120 Hz Display wi...
# ..                                                 ...
# 946  6.53 inches, 1176 x 2400 px Display with Large...
# 949                   8 inches, 2200 x 2480 px Display
# 961  6.43 inches, 1440 x 3200 px, 120 Hz Display wi...
# 963  6.7 inches, 1080 x 2400 px, 120 Hz Display wit...
# 971  6.6 inches, 1080 x 2460 px, 144 Hz Display wit...
#
#                                                 camera  \
# 7    200 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# 12   50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 22   64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 23   48 MP + 8 MP + 2 MP Triple Rear & 13 MP Front ...
# 31   108 MP + 8 MP + 2 MP Triple Rear & 16 MP Front...
# ..                                                 ...
# 946          40 MP Quad Rear & 32 MP Dual Front Camera
# 949                                   Foldable Display
# 961  50 MP + 50 MP + 50 MP Triple Rear & 32 MP Fron...
# 963  64 MP + 20 MP + 2 MP Triple Rear & 32 MP + 32 ...
# 971  64 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
#
#                                   card                                 os
# 7            Memory Card Not Supported                        Android v12
# 12                         Android v12                        No FM Radio
# 22     Memory Card (Hybrid), upto 1 TB                        Android v11
# 23     Memory Card (Hybrid), upto 1 TB                        Android v12
# 31           Memory Card Not Supported                        Android v13
# ..                                 ...                                ...
# 946  Memory Card (Hybrid), upto 256 GB                        Android v10
# 949             48 MP Quad Rear Camera  Memory Card (Hybrid), upto 256 GB
# 961                        Android v13                        No FM Radio
# 963                        Android v13                        No FM Radio
# 971          Memory Card Not Supported                        Android v12
#
# [158 rows x 11 columns]

# %%
df.loc[[439,480,740]]
# Out:
#                                 model   price  rating  \
# 439            Apple iPhone SE 3 2022   43900     NaN
# 480  Huawei Mate 50 RS Porsche Design  239999    81.0
# 740                 Apple iPhone SE 4   49990    60.0
#
#                                                  sim  \
# 439          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 480  Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 740          Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                             processor             ram  \
# 439        Bionic  A15, Hexa Core, 3.22 GHz Processor   64 GB inbuilt
# 480  Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor  512 GB inbuilt
# 740        Bionic  A15, Hexa Core, 3.22 GHz Processor   64 GB inbuilt
#
#                                      battery  \
# 439        4.7 inches, 750 x 1334 px Display
# 480  4700 mAh Battery with 66W Fast Charging
# 740        6.1 inches, 750 x 1580 px Display
#
#                                          display  \
# 439               12 MP Rear & 7 MP Front Camera
# 480  6.74 inches, 1212 x 2616 px, 120 Hz Display
# 740            12 MP Rear & 10.8 MP Front Camera
#
#                                                 camera  \
# 439                          Memory Card Not Supported
# 480  50 MP + 48 MP + 13 MP Triple Rear & 13 MP Fron...
# 740                          Memory Card Not Supported
#
#                                   card                os
# 439                            iOS v15       No FM Radio
# 480  Memory Card (Hybrid), upto 256 GB  Hongmeng OS v3.0
# 740                            iOS v16       No FM Radio

# %%
df.loc[439 , 'ram'] = 'Apple iPhone SE 3'

# %%
df.loc[439 , 'ram'] = '4 GB RAM, 64 GB inbuilt'

# %%
df.loc[480 , 'ram'] = '12 GB RAM, 512 GB inbuilt'

# %%
df.loc[740 , 'ram'] = '8 GB RAM, 64 GB inbuilt'

# %% [markdown]
# #### some iphones have data shifted in battery to the last row so we have to fix it.

# %%
df.loc[[111,149 , 307,363,439,448,616,824,879,880]]
# Out:
#                       model   price  rating  \
# 111         Apple iPhone 12   51999    74.0
# 149    Apple iPhone 12 Mini   40999    74.0
# 307        Apple iPhone 12    55999    75.0
# 363   Apple iPhone 12 Mini    45999    75.0
# 439  Apple iPhone SE 3 2022   43900     NaN
# 448     Apple iPhone 15 Pro  130990    75.0
# 616    Apple iPhone 12 Pro   139900    80.0
# 824    Apple iPhone 12 Pro   119900    80.0
# 879   Apple iPhone 12 Mini    55999    75.0
# 880        Apple iPhone 12    67999    76.0
#
#                                          sim  \
# 111  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 149  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 307  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 363  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 439  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 448  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 616  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 824  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 879  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 880  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                       processor                       ram  \
# 111    Bionic A14, Hexa Core, 3.1 GHz Processor   4 GB RAM, 64 GB inbuilt
# 149    Bionic A14, Hexa Core, 3.1 GHz Processor   4 GB RAM, 64 GB inbuilt
# 307    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 128 GB inbuilt
# 363    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 128 GB inbuilt
# 439  Bionic  A15, Hexa Core, 3.22 GHz Processor   4 GB RAM, 64 GB inbuilt
# 448                                 Bionic  A16  8 GB RAM, 128 GB inbuilt
# 616    Bionic A14, Hexa Core, 3.1 GHz Processor  6 GB RAM, 512 GB inbuilt
# 824    Bionic A14, Hexa Core, 3.1 GHz Processor  6 GB RAM, 256 GB inbuilt
# 879    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 256 GB inbuilt
# 880    Bionic A14, Hexa Core, 3.1 GHz Processor  4 GB RAM, 256 GB inbuilt
#
#                                                battery  \
# 111  6.1 inches, 1170 x 2532 px Display with Large ...
# 149                 5.4 inches, 1080 x 2340 px Display
# 307  6.1 inches, 1170 x 2532 px Display with Large ...
# 363                 5.4 inches, 1080 x 2340 px Display
# 439                  4.7 inches, 750 x 1334 px Display
# 448  6.06 inches, 1170 x 2532 px, 120 Hz Display wi...
# 616  6.1 inches, 1170 x 2532 px Display with Large ...
# 824  6.1 inches, 1170 x 2532 px Display with Large ...
# 879                 5.4 inches, 1080 x 2340 px Display
# 880  6.1 inches, 1170 x 2532 px Display with Large ...
#
#                                                display  \
# 111       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 149       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 307       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 363       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 439                     12 MP Rear & 7 MP Front Camera
# 448  50 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 616  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 824  12 MP + 12 MP + 12 MP Triple Rear & 12 MP Fron...
# 879       12 MP + 12 MP Dual Rear & 12 MP Front Camera
# 880       12 MP + 12 MP Dual Rear & 12 MP Front Camera
#
#                         camera       card           os
# 111  Memory Card Not Supported    iOS v14  No FM Radio
# 149  Memory Card Not Supported    iOS v14  No FM Radio
# 307  Memory Card Not Supported    iOS v14  No FM Radio
# 363  Memory Card Not Supported    iOS v14  No FM Radio
# 439  Memory Card Not Supported    iOS v15  No FM Radio
# 448  Memory Card Not Supported    iOS v15  No FM Radio
# 616  Memory Card Not Supported  iOS v14.0  No FM Radio
# 824  Memory Card Not Supported  iOS v14.0  No FM Radio
# 879  Memory Card Not Supported    iOS v14  No FM Radio
# 880  Memory Card Not Supported    iOS v14  No FM Radio

# %%
df.loc[[111,149 , 307,363,439,448,616,824,879,880] ,'battery': ] = df.loc[[111,149 , 307,363,439,448,616,824,879,880] ,'battery': ].shift(1 , axis = 1)

# %% [markdown]
# #### Some rows have issue with camera values :

# %%
temp = df.iloc[[392,69,98,155,159,236,271,306,365,376,479,501,563,564,602,665,684,690,702,707,768,818,861,900,911,949,968]]
temp
# Out:
#                           model   price  rating  \
# 392           OPPO Find N2 Flip   70990    88.0
# 69             Oppo Find N Fold   99990     NaN
# 98               Vivo X Fold 5G  106990     NaN
# 155             Nokia 2780 Flip    4990     NaN
# 159             Oppo Find N2 5G   94990     NaN
# 236        Xiaomi Mix Fold 2 5G  106990     NaN
# 271           Nokia 2720 V Flip    6199     NaN
# 306     Samsung Galaxy Z Flip 3   69999    84.0
# 365            OPPO Find N Flip   89990    88.0
# 376             Nokia 2660 Flip    4649     NaN
# 479            Vivo X Fold Plus  113990     NaN
# 501  Samsung Galaxy Z Flip 4 5G   89999    88.0
# 563     Samsung Galaxy Z Fold 3  110999    89.0
# 564                  LG Wing 5G   54999    89.0
# 602                Oukitel WP21   22990    82.0
# 665                LG V60 ThinQ   79990     NaN
# 684              Oppo Find N 5G   92249     NaN
# 690                      OPPO X  134999    86.0
# 702  Asus ROG Phone 6D Ultimate  107990     NaN
# 707            Huawei Mate Xs 2  162990    89.0
# 768          Xiaomi Mi Mix Fold  109990     NaN
# 818                CAT S22 Flip   14999     NaN
# 861         Royole FlexPai 3 5G  149999    87.0
# 900    Samsung Galaxy Z Fold 4   163980     NaN
# 911             Vivo X Fold 5G   118990     NaN
# 949               Huawei Mate X  169000     NaN
# 968               Vivo X Fold 2  119990     NaN
#
#                                                    sim  \
# 392          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 69             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 98             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 155                            Dual Sim, 3G, 4G, Wi-Fi
# 159            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 236  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 271                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 306          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 365          Single Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 376                                   Dual Sim, 3G, 4G
# 479            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 501            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 563            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 564            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 602                     Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 665            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 684            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 690                   Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 702            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 707    Dual Sim, 3G, 4G, VoLTE, Wi-Fi, NFC, IR Blaster
# 768  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 818                   Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 861                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 900            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 911            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 949  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 968            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                              processor  \
# 392  Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 69   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 98       Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 155     Snapdragon QM215, Quad Core, 1.3 GHz Processor
# 159   Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 236  Snapdragon  8+ Gen1 , Octa Core, 3.2 GHz Proce...
# 271      Snapdragon 205 , Dual Core, 1.1 GHz Processor
# 306      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 365      Dimensity 9000, Octa Core, 3.05 GHz Processor
# 376                                            No Wifi
# 479   Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 501  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 563      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 564    Snapdragon  765G , Octa Core, 2.4 GHz Processor
# 602            Helio G99, Octa Core, 2.2 GHz Processor
# 665     Snapdragon  865, Octa Core, 2.84 GHz Processor
# 684     Snapdragon  888, Octa Core, 2.84 GHz Processor
# 690      Snapdragon 865, Octa Core, 2.84 GHz Processor
# 702  Dimensity 9000 Plus, Octa Core, 3.2 GHz Processor
# 707      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 768    Snapdragon  888 , Octa Core, 2.84 GHz Processor
# 818         Qualcomm 215, Quad Core, 1.3 GHz Processor
# 861      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 900  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 911      Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 949          Kirin  990, Octa Core, 2.86 GHz Processor
# 968    Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
#
#                            ram                                  battery  \
# 392   8 GB RAM, 256 GB inbuilt  4300 mAh Battery with 44W Fast Charging
# 69    8 GB RAM, 256 GB inbuilt  5000 mAh Battery with 67W Fast Charging
# 98   12 GB RAM, 256 GB inbuilt  4600 mAh Battery with 66W Fast Charging
# 155   4 GB RAM, 512 MB inbuilt                         1450 mAh Battery
# 159  12 GB RAM, 256 GB inbuilt  4520 mAh Battery with 67W Fast Charging
# 236  12 GB RAM, 256 GB inbuilt  4500 mAh Battery with 67W Fast Charging
# 271   512 MB RAM, 4 GB inbuilt                         1500 mAh Battery
# 306   8 GB RAM, 128 GB inbuilt  3300 mAh Battery with 15W Fast Charging
# 365   8 GB RAM, 128 GB inbuilt  4300 mAh Battery with 44W Fast Charging
# 376                Unisoc T107                48 MB RAM, 128 MB inbuilt
# 479  12 GB RAM, 256 GB inbuilt  4730 mAh Battery with 80W Fast Charging
# 501   8 GB RAM, 128 GB inbuilt  3700 mAh Battery with 25W Fast Charging
# 563  12 GB RAM, 256 GB inbuilt  4400 mAh Battery with 25W Fast Charging
# 564   8 GB RAM, 128 GB inbuilt      4000 mAh Battery with Fast Charging
# 602  12 GB RAM, 256 GB inbuilt  9800 mAh Battery with 66W Fast Charging
# 665   8 GB RAM, 128 GB inbuilt      5000 mAh Battery with Fast Charging
# 684   8 GB RAM, 256 GB inbuilt  4500 mAh Battery with 33W Fast Charging
# 690   8 GB RAM, 256 GB inbuilt  4000 mAh Battery with 45W Fast Charging
# 702  16 GB RAM, 512 GB inbuilt  6000 mAh Battery with 65W Fast Charging
# 707   8 GB RAM, 512 GB inbuilt  4600 mAh Battery with 66W Fast Charging
# 768  12 GB RAM, 256 GB inbuilt  5020 mAh Battery with 67W Fast Charging
# 818    2 GB RAM, 16 GB inbuilt                         2000 mAh Battery
# 861   8 GB RAM, 128 GB inbuilt                         3360 mAh Battery
# 900    12 GB RAM, 1 TB inbuilt  4400 mAh Battery with 25W Fast Charging
# 911  12 GB RAM, 512 GB inbuilt  4600 mAh Battery with 66W Fast Charging
# 949   8 GB RAM, 512 GB inbuilt  4500 mAh Battery with 55W Fast Charging
# 968  12 GB RAM, 256 GB inbuilt  4800 mAh Battery with 66W Fast Charging
#
#                                                display  \
# 392  6.8 inches, 1080 x 2520 px, 120 Hz Display wit...
# 69   7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 98         8.03 inches, 1916 x 2160 px, 120 Hz Display
# 155                   2.7 inches, 240 x 320 px Display
# 159  7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 236  8.02 inches, 1914 x 2160 px, 120 Hz Display wi...
# 271                   2.8 inches, 240 x 320 px Display
# 306  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 365  6.8 inches, 1200 x 2400 px, 120 Hz Display wit...
# 376                                   1450 mAh Battery
# 479  8.03 inches, 1916 x 2160 px, 120 Hz Display wi...
# 501  6.7 inches, 1080 x 2640 px, 120 Hz Display wit...
# 563  7.6 inches, 1768 x 2208 px, 120 Hz Display wit...
# 564                 6.8 inches, 1080 x 2460 px Display
# 602        6.78 inches, 1080 x 2400 px, 120 Hz Display
# 665  6.8 inches, 1080 x 2460 px Display with Punch ...
# 684  7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 690                 7.4 inches, 1440 x 3200 px Display
# 702        6.78 inches, 1080 x 2448 px, 165 Hz Display
# 707  7.8 inches, 2200 x 2480 px, 120 Hz Display wit...
# 768         8.01 inches, 1860 x 2480 px, 90 Hz Display
# 818                     4 inches, 480 x 640 px Display
# 861                 7.2 inches, 1440 x 1920 px Display
# 900  7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 911        8.03 inches, 1916 x 2160 px, 120 Hz Display
# 949                   8 inches, 2200 x 2480 px Display
# 968        8.03 inches, 1916 x 2160 px, 120 Hz Display
#
#                                camera  \
# 392    Foldable Display, Dual Display
# 69     Foldable Display, Dual Display
# 98                   Foldable Display
# 155                      Dual Display
# 159    Foldable Display, Dual Display
# 236    Foldable Display, Dual Display
# 271                      Dual Display
# 306    Foldable Display, Dual Display
# 365    Foldable Display, Dual Display
# 376  2.8 inches, 240 x 320 px Display
# 479    Foldable Display, Dual Display
# 501    Foldable Display, Dual Display
# 563    Foldable Display, Dual Display
# 564                      Dual Display
# 602                      Dual Display
# 665                      Dual Display
# 684    Foldable Display, Dual Display
# 690                      Dual Display
# 702                      Dual Display
# 707                  Foldable Display
# 768    Foldable Display, Dual Display
# 818                      Dual Display
# 861    Foldable Display, Dual Display
# 900    Foldable Display, Dual Display
# 911                  Foldable Display
# 949                  Foldable Display
# 968                  Foldable Display
#
#                                                   card  \
# 392        50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 69   64 MP + 10 MP + 8 MP Triple Rear & 32 MP Front...
# 98                50 MP Quad Rear & 16 MP Front Camera
# 155                                   5 MP Rear Camera
# 159  50 MP + 48 MP + 32 MP Triple Rear & 32 MP + 32...
# 236  50 MP + 13 MP + 8 MP Triple Rear & 20 MP Front...
# 271                                   2 MP Rear Camera
# 306       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 365        50 MP + 8 MP Dual Rear & 32 MP Front Camera
# 376                                       Dual Display
# 479  50 MP Quad Rear & 16 MP + 16 MP Dual Front Camera
# 501       12 MP + 12 MP Dual Rear & 10 MP Front Camera
# 563  12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 ...
# 564  64 MP + 13 MP + 12 MP Triple Rear & 32 MP Fron...
# 602  64 MP + 20 MP + 2 MP Triple Rear & Main Front ...
# 665  64 MP + 13 MP + 0.3 MP Triple Rear & 10 MP Fro...
# 684  50 MP + 16 MP + 13 MP Triple Rear & 32 MP Fron...
# 690  64 MP + 16 MP + 12 MP Triple Rear & 16 MP Fron...
# 702  50 MP + 13 MP + 5 MP Triple Rear & 12 MP Front...
# 707  50 MP + 13 MP + 8 MP Triple Rear & 10.7 MP Fro...
# 768  108 MP + 13 MP + 8 MP Triple Rear & 20 MP Fron...
# 818                      5 MP Rear & 2 MP Front Camera
# 861  64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 900  50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 911               50 MP Quad Rear & 16 MP Front Camera
# 949                             48 MP Quad Rear Camera
# 968  50 MP + 50 MP + 10 MP Triple Rear & 32 MP Fron...
#
#                                      os
# 392           Memory Card Not Supported
# 69                          Android v12
# 98                          Android v12
# 155   Memory Card Supported, upto 32 GB
# 159           Memory Card Not Supported
# 236                         Android v12
# 271               Memory Card Supported
# 306           Memory Card Not Supported
# 365           Memory Card Not Supported
# 376                  0.3 MP Rear Camera
# 479                         Android v12
# 501           Memory Card Not Supported
# 563                         Android v11
# 564     Memory Card (Hybrid), upto 2 TB
# 602                Memory Card (Hybrid)
# 665     Memory Card (Hybrid), upto 2 TB
# 684                         Android v11
# 690                         Android v11
# 702           Memory Card Not Supported
# 707   Memory Card (Hybrid), upto 256 GB
# 768                         Android v10
# 818  Memory Card Supported, upto 128 GB
# 861  Memory Card Supported, upto 256 GB
# 900                         Android v12
# 911                         Android v12
# 949   Memory Card (Hybrid), upto 256 GB
# 968                         Android v12

# %%
# we have to shift left the memory to camera :
df.loc[[392,69,98,155,159,236,271,306,365,479,501,563,564,602,665,684,690,702,707,768,818,861,900,911,949,968],['camera' , 'card']] = df.loc[[392,69,98,155,159,236,271,306,365,479,501,563,564,602,665,684,690,702,707,768,818,861,900,911,949,968],['camera' , 'card']].shift(-1 , axis=1)

# %%
mask = temp['os'].str.contains('Memory Card', na=False)
cols = ['card', 'os']
temp.loc[mask, cols] = temp.loc[mask, cols].shift(-1, axis=1)

# %%
df.iloc[temp.index] = temp

# %%
df.loc[temp.index , 'os'].fillna('Android v12' , inplace=True)

# %%
temp = df[~df['card'].str.contains('Memory')]

# %%
df.loc[temp.index , ['card' , 'os']] = temp.loc[:,['card' , 'os']].shift(1,axis=1)

# %%
df['card'] = df['card'].fillna('Memory Card Supported')

# %%
temp = df[df['os'].str.contains('MP' , na = False)]
temp
# Out:
#                         model   price  rating  \
# 69           Oppo Find N Fold   99990     NaN
# 98             Vivo X Fold 5G  106990     NaN
# 236      Xiaomi Mix Fold 2 5G  106990     NaN
# 321   Samsung Galaxy Z Fold 4  154998     NaN
# 322          Royole FlexPai 2  109999    87.0
# 479          Vivo X Fold Plus  113990     NaN
# 563   Samsung Galaxy Z Fold 3  110999    89.0
# 684            Oppo Find N 5G   92249     NaN
# 690                    OPPO X  134999    86.0
# 768        Xiaomi Mi Mix Fold  109990     NaN
# 849    Nokia 5710 XpressAudio    4799     NaN
# 900  Samsung Galaxy Z Fold 4   163980     NaN
# 911           Vivo X Fold 5G   118990     NaN
# 968             Vivo X Fold 2  119990     NaN
#
#                                                    sim  \
# 69             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 98             Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 236  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 321            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 322                 Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 479            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 563            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 684            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 690                   Single Sim, 3G, 4G, VoLTE, Wi-Fi
# 768  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 849                                   Dual Sim, 3G, 4G
# 900            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 911            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 968            Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
#
#                                              processor  \
# 69   Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 98       Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 236  Snapdragon  8+ Gen1 , Octa Core, 3.2 GHz Proce...
# 321  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 322      Snapdragon 865, Octa Core, 2.84 GHz Processor
# 479   Snapdragon 8+ Gen1, Octa Core, 3.2 GHz Processor
# 563      Snapdragon 888, Octa Core, 2.84 GHz Processor
# 684     Snapdragon  888, Octa Core, 2.84 GHz Processor
# 690      Snapdragon 865, Octa Core, 2.84 GHz Processor
# 768    Snapdragon  888 , Octa Core, 2.84 GHz Processor
# 849                                            No Wifi
# 900  Snapdragon  8+ Gen1, Octa Core, 3.2 GHz Processor
# 911      Snapdragon 8 Gen1, Octa Core, 3 GHz Processor
# 968    Snapdragon 8 Gen2, Octa Core, 3.2 GHz Processor
#
#                            ram                                  battery  \
# 69    8 GB RAM, 256 GB inbuilt  5000 mAh Battery with 67W Fast Charging
# 98   12 GB RAM, 256 GB inbuilt  4600 mAh Battery with 66W Fast Charging
# 236  12 GB RAM, 256 GB inbuilt  4500 mAh Battery with 67W Fast Charging
# 321  12 GB RAM, 256 GB inbuilt  4400 mAh Battery with 25W Fast Charging
# 322   8 GB RAM, 128 GB inbuilt                         4450 mAh Battery
# 479  12 GB RAM, 256 GB inbuilt  4730 mAh Battery with 80W Fast Charging
# 563  12 GB RAM, 256 GB inbuilt  4400 mAh Battery with 25W Fast Charging
# 684   8 GB RAM, 256 GB inbuilt  4500 mAh Battery with 33W Fast Charging
# 690   8 GB RAM, 256 GB inbuilt  4000 mAh Battery with 45W Fast Charging
# 768  12 GB RAM, 256 GB inbuilt  5020 mAh Battery with 67W Fast Charging
# 849                Unisoc T107                48 MB RAM, 128 MB inbuilt
# 900    12 GB RAM, 1 TB inbuilt  4400 mAh Battery with 25W Fast Charging
# 911  12 GB RAM, 512 GB inbuilt  4600 mAh Battery with 66W Fast Charging
# 968  12 GB RAM, 256 GB inbuilt  4800 mAh Battery with 66W Fast Charging
#
#                                                display  \
# 69   7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 98         8.03 inches, 1916 x 2160 px, 120 Hz Display
# 236  8.02 inches, 1914 x 2160 px, 120 Hz Display wi...
# 321  7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 322                 7.8 inches, 1440 x 1920 px Display
# 479  8.03 inches, 1916 x 2160 px, 120 Hz Display wi...
# 563  7.6 inches, 1768 x 2208 px, 120 Hz Display wit...
# 684  7.1 inches, 1792 x 1920 px, 120 Hz Display wit...
# 690                 7.4 inches, 1440 x 3200 px Display
# 768         8.01 inches, 1860 x 2480 px, 90 Hz Display
# 849                                   1450 mAh Battery
# 900  7.6 inches, 1812 x 2176 px, 120 Hz Display wit...
# 911        8.03 inches, 1916 x 2160 px, 120 Hz Display
# 968        8.03 inches, 1916 x 2160 px, 120 Hz Display
#
#                                camera                   card  \
# 69     Foldable Display, Dual Display  Memory Card Supported
# 98                   Foldable Display  Memory Card Supported
# 236    Foldable Display, Dual Display  Memory Card Supported
# 321    Foldable Display, Dual Display  Memory Card Supported
# 322    Foldable Display, Dual Display  Memory Card Supported
# 479    Foldable Display, Dual Display  Memory Card Supported
# 563    Foldable Display, Dual Display  Memory Card Supported
# 684    Foldable Display, Dual Display  Memory Card Supported
# 690                      Dual Display  Memory Card Supported
# 768    Foldable Display, Dual Display  Memory Card Supported
# 849  2.4 inches, 240 x 320 px Display  Memory Card Supported
# 900    Foldable Display, Dual Display  Memory Card Supported
# 911                  Foldable Display  Memory Card Supported
# 968                  Foldable Display  Memory Card Supported
#
#                                                     os
# 69   64 MP + 10 MP + 8 MP Triple Rear & 32 MP Front...
# 98                50 MP Quad Rear & 16 MP Front Camera
# 236  50 MP + 13 MP + 8 MP Triple Rear & 20 MP Front...
# 321  50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 322  64 MP + 16 MP + 8 MP Triple Rear & 32 MP Front...
# 479  50 MP Quad Rear & 16 MP + 16 MP Dual Front Camera
# 563  12 MP + 12 MP + 12 MP Triple Rear & 10 MP + 4 ...
# 684  50 MP + 16 MP + 13 MP Triple Rear & 32 MP Fron...
# 690  64 MP + 16 MP + 12 MP Triple Rear & 16 MP Fron...
# 768  108 MP + 13 MP + 8 MP Triple Rear & 20 MP Fron...
# 849                                 0.3 MP Rear Camera
# 900  50 MP + 12 MP + 10 MP Triple Rear & 10 MP + 4 ...
# 911               50 MP Quad Rear & 16 MP Front Camera
# 968  50 MP + 50 MP + 10 MP Triple Rear & 32 MP Fron...

# %%
df.loc[temp.index , ['camera' , 'os']] =  temp[['camera' , 'os']].shift(-1 , axis = 1)

# %%
df.loc[df['camera'].str.contains('Display', na=False), 'camera'] = 0

# %%
df.loc[~df['os'].str.contains('v|OS|Android' , na = True) , ['os']] = 0

# %%
df[~df.loc[:,'battery'].str.contains("mAh" , na = True)]
# Out:
#                       model  price  rating  \
# 376         Nokia 2660 Flip   4649     NaN
# 632         Nokia 2760 Flip   5490     NaN
# 740       Apple iPhone SE 4  49990    60.0
# 828             LG Folder 2  11999     NaN
# 849  Nokia 5710 XpressAudio   4799     NaN
#
#                                          sim  \
# 376                         Dual Sim, 3G, 4G
# 632                  Dual Sim, 3G, 4G, Wi-Fi
# 740  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 828                Single Sim, 3G, 4G, Wi-Fi
# 849                         Dual Sim, 3G, 4G
#
#                                       processor  \
# 376                                     No Wifi
# 632                            1450 mAh Battery
# 740  Bionic  A15, Hexa Core, 3.22 GHz Processor
# 828                      1 GB RAM, 8 GB inbuilt
# 849                                     No Wifi
#
#                                   ram                            battery  \
# 376                       Unisoc T107          48 MB RAM, 128 MB inbuilt
# 632  3.6 inches, 240 x 320 px Display      5 MP Rear & 5 MP Front Camera
# 740           8 GB RAM, 64 GB inbuilt  6.1 inches, 750 x 1580 px Display
# 828                  1470 mAh Battery   2.8 inches, 240 x 320 px Display
# 849                       Unisoc T107          48 MB RAM, 128 MB inbuilt
#
#                                display                     camera  \
# 376                   1450 mAh Battery                          0
# 632  Memory Card Supported, upto 32 GB                 Kaios v3.0
# 740  12 MP Rear & 10.8 MP Front Camera  Memory Card Not Supported
# 828                   2 MP Rear Camera      Memory Card Supported
# 849                   1450 mAh Battery         0.3 MP Rear Camera
#
#                       card       os
# 376  Memory Card Supported        0
# 632  Memory Card Supported        0
# 740  Memory Card Supported  iOS v16
# 828  Memory Card Supported        0
# 849  Memory Card Supported     None

# %%
df.loc[740 , 'battery'] = 0

# %%
df.loc[: , 'display'].str.contains("Display").sum()
# Out:
# np.int64(969)

# %%
df[~df.loc[: , 'camera'].str.contains("MP" , na = True)]
# Out:
#                  model  price  rating  \
# 632    Nokia 2760 Flip   5490     NaN
# 740  Apple iPhone SE 4  49990    60.0
# 828        LG Folder 2  11999     NaN
#
#                                          sim  \
# 632                  Dual Sim, 3G, 4G, Wi-Fi
# 740  Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 828                Single Sim, 3G, 4G, Wi-Fi
#
#                                       processor  \
# 632                            1450 mAh Battery
# 740  Bionic  A15, Hexa Core, 3.22 GHz Processor
# 828                      1 GB RAM, 8 GB inbuilt
#
#                                   ram                           battery  \
# 632  3.6 inches, 240 x 320 px Display     5 MP Rear & 5 MP Front Camera
# 740           8 GB RAM, 64 GB inbuilt                                 0
# 828                  1470 mAh Battery  2.8 inches, 240 x 320 px Display
#
#                                display                     camera  \
# 632  Memory Card Supported, upto 32 GB                 Kaios v3.0
# 740  12 MP Rear & 10.8 MP Front Camera  Memory Card Not Supported
# 828                   2 MP Rear Camera      Memory Card Supported
#
#                       card       os
# 632  Memory Card Supported        0
# 740  Memory Card Supported  iOS v16
# 828  Memory Card Supported        0

# %%
df.loc[740 , 'camera'] = 0

# %%
df.loc[: , 'card'].str.contains("Memory" , na = True).sum()
# Out:
# np.int64(974)

# %%
df.loc[: , 'os'].str.contains("v|OS|Android" , na = True).sum()
# Out:
# np.int64(974)

# %%
# some phone is a feacher phone
df.loc[[155,271,376,632,828,849,632]]
# Out:
#                       model  price  rating                             sim  \
# 155         Nokia 2780 Flip   4990     NaN         Dual Sim, 3G, 4G, Wi-Fi
# 271       Nokia 2720 V Flip   6199     NaN  Dual Sim, 3G, 4G, VoLTE, Wi-Fi
# 376         Nokia 2660 Flip   4649     NaN                Dual Sim, 3G, 4G
# 632         Nokia 2760 Flip   5490     NaN         Dual Sim, 3G, 4G, Wi-Fi
# 828             LG Folder 2  11999     NaN       Single Sim, 3G, 4G, Wi-Fi
# 849  Nokia 5710 XpressAudio   4799     NaN                Dual Sim, 3G, 4G
# 632         Nokia 2760 Flip   5490     NaN         Dual Sim, 3G, 4G, Wi-Fi
#
#                                           processor  \
# 155  Snapdragon QM215, Quad Core, 1.3 GHz Processor
# 271   Snapdragon 205 , Dual Core, 1.1 GHz Processor
# 376                                         No Wifi
# 632                                1450 mAh Battery
# 828                          1 GB RAM, 8 GB inbuilt
# 849                                         No Wifi
# 632                                1450 mAh Battery
#
#                                   ram                           battery  \
# 155          4 GB RAM, 512 MB inbuilt                  1450 mAh Battery
# 271          512 MB RAM, 4 GB inbuilt                  1500 mAh Battery
# 376                       Unisoc T107         48 MB RAM, 128 MB inbuilt
# 632  3.6 inches, 240 x 320 px Display     5 MP Rear & 5 MP Front Camera
# 828                  1470 mAh Battery  2.8 inches, 240 x 320 px Display
# 849                       Unisoc T107         48 MB RAM, 128 MB inbuilt
# 632  3.6 inches, 240 x 320 px Display     5 MP Rear & 5 MP Front Camera
#
#                                display                 camera  \
# 155   2.7 inches, 240 x 320 px Display                      0
# 271   2.8 inches, 240 x 320 px Display                      0
# 376                   1450 mAh Battery                      0
# 632  Memory Card Supported, upto 32 GB             Kaios v3.0
# 828                   2 MP Rear Camera  Memory Card Supported
# 849                   1450 mAh Battery     0.3 MP Rear Camera
# 632  Memory Card Supported, upto 32 GB             Kaios v3.0
#
#                                   card    os
# 155  Memory Card Supported, upto 32 GB  None
# 271              Memory Card Supported  None
# 376              Memory Card Supported     0
# 632              Memory Card Supported     0
# 828              Memory Card Supported     0
# 849              Memory Card Supported  None
# 632              Memory Card Supported     0

# %%
df = df.drop([155, 271, 376, 632, 828, 849])

# %%
# reset index of our dataset
df = df.reset_index(drop=True)

# %%
df['rating'].fillna(df['rating'].median() , inplace=True)
# Out:
# /tmp/ipykernel_17/2783515639.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['rating'].fillna(df['rating'].median() , inplace=True)

# %%
df['model'] = df['model'].str.strip()

# %%
df.to_excel("cleaned_data.xlsx" , index = False)

# %%
df.to_csv("cleaned_data.csv" , index = False)
